# %%
import cdt
from cdt import SETTINGS
import pandas as pd
from pandas import Series

SETTINGS.verbose = True
#SETTINGS.NJOBS = 16
#SETTINGS.GPU = 1
import networkx as nx
import matplotlib.pyplot as plt
plt.axis('off')
# Out:
# Detecting 1 CUDA device(s).
# (0.0, 1.0, 0.0, 1.0)

# %%
# Load data


data = pd.read_csv("exp_merge_mix.csv")
top_feature_list = ['Readable', 'BW-Avg-number-of-identifiers', 'BW-Avg-comments', 'BW-Max-indentation',
        'BW-Max-char', 'BW-Avg-periods', 'BW-Avg-Assignment', 'BW-Max-line-length',
        'New-Semantic-Text-Coherence-Standard-@-0.1', 'BW-Avg-Identifiers-Length', "New-Number-of-senses-AVG",
                    'BW-Max-Single-identifiers', 'BW-Max-number-of-identifiers']

# %%
# top12
feature_list = []
for row in data:
    feature_list.append(row)


#
for element in feature_list:
    if element not in top_feature_list:
        data.drop([element], axis=1, inplace=True)


print(data.head())
# Out:
#    New-Number-of-senses-AVG  New-Semantic-Text-Coherence-Standard-@-0.1  \
# 0                  9.882353                                           6
# 1                 10.181818                                           5
# 2                  6.444444                                           6
# 3                  6.500000                                           5
# 4                 11.235294                                           5
#
#    BW-Avg-Identifiers-Length  BW-Avg-number-of-identifiers  \
# 0                     6.8889                        1.1818
# 1                     6.9000                        1.5455
# 2                    10.1818                        2.7143
# 3                     9.5455                        1.0000
# 4                     8.8750                        0.7000
#
#    BW-Max-number-of-identifiers  BW-Max-Single-identifiers  BW-Avg-Assignment  \
# 0                             5                          4             0.1818
# 1                             5                          4             0.1818
# 2                             9                          5             0.4286
# 3                             5                          2             0.2143
# 4                             2                          1             0.0000
#
#    BW-Avg-periods  BW-Max-indentation  BW-Avg-comments  BW-Max-char  \
# 0          0.1818                   6              0.0           17
# 1          0.7273                   4              0.0           19
# 2          0.2857                   4              0.0           17
# 3          0.0000                   3              0.5           20
# 4          0.3000                   3              0.3           11
#
#    BW-Max-line-length  Readable
# 0                  59      2.99
# 1                  66      3.74
# 2                 110      2.69
# 3                  77      4.03
# 4                  51      4.19

# %%
# PC Algorithm to find skeleton
model = cdt.causality.graph.PC()
skeleton = model.predict(data)

# output_graph = skeleton

# Pairwise setting
# Add one-way noise to distinguish causal relationship
model = cdt.causality.pairwise.ANM()
output_graph = model.predict(data, skeleton)


# Visualize causality graph
options = {
        "node_color": "#A0CBE2",
        "width": 1,
        "node_size":600,
        "edge_cmap": plt.cm.Blues,
        "with_labels": True,
    }

nx.draw_networkx(output_graph, nx.shell_layout(output_graph), **options)
# plt.savefig("result.png")
plt.show()

# %%
# top 13
data = pd.read_csv("exp_merge_mix.csv")
top_feature_list = ['Readable', 'BW-Avg-number-of-identifiers', 'BW-Avg-comments', 'BW-Max-indentation',
        'BW-Max-char', 'BW-Avg-periods', 'BW-Avg-Assignment', 'BW-Max-line-length',
        'New-Semantic-Text-Coherence-Standard-@-0.1', 'BW-Avg-Identifiers-Length', "New-Number-of-senses-AVG",
                    'BW-Max-Single-identifiers', 'BW-Max-number-of-identifiers', "New-Identifiers-words-AVG"]

feature_list = []
for row in data:
    feature_list.append(row)

#
for element in feature_list:
    if element not in top_feature_list:
        data.drop([element], axis=1, inplace=True)
        
        # PC Algorithm to find skeleton
model = cdt.causality.graph.PC()
skeleton = model.predict(data)

# output_graph = skeleton

# Pairwise setting
# Add one-way noise to distinguish causal relationship
model = cdt.causality.pairwise.ANM()
output_graph = model.predict(data, skeleton)


# Visualize causality graph
options = {
        "node_color": "#A0CBE2",
        "width": 1,
        "node_size":600,
        "edge_cmap": plt.cm.Blues,
        "with_labels": True,
    }

nx.draw_networkx(output_graph, nx.shell_layout(output_graph), **options)
# plt.savefig("result.png")
plt.show()

# %%
# top 14
data = pd.read_csv("exp_merge_mix.csv")
top_feature_list = ['Readable', 'BW-Avg-number-of-identifiers', 'BW-Avg-comments', 'BW-Max-indentation',
        'BW-Max-char', 'BW-Avg-periods', 'BW-Avg-Assignment', 'BW-Max-line-length',
        'New-Semantic-Text-Coherence-Standard-@-0.1', 'BW-Avg-Identifiers-Length', "New-Number-of-senses-AVG",
                    'BW-Max-Single-identifiers', 'BW-Max-number-of-identifiers', "New-Identifiers-words-AVG", "New-Number-of-senses-MAX"]

feature_list = []
for row in data:
    feature_list.append(row)

#
for element in feature_list:
    if element not in top_feature_list:
        data.drop([element], axis=1, inplace=True)
        
        # PC Algorithm to find skeleton
model = cdt.causality.graph.PC()
skeleton = model.predict(data)

# output_graph = skeleton

# Pairwise setting
# Add one-way noise to distinguish causal relationship
model = cdt.causality.pairwise.ANM()
output_graph = model.predict(data, skeleton)


# Visualize causality graph
options = {
        "node_color": "#A0CBE2",
        "width": 1,
        "node_size":600,
        "edge_cmap": plt.cm.Blues,
        "with_labels": True,
    }

nx.draw_networkx(output_graph, nx.shell_layout(output_graph), **options)
# plt.savefig("result.png")
plt.show()
